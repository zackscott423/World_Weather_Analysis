# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citpy module to determine city based on the latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 651

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging
print("Beginning data retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
    # Create endpoint URL with each city
    city_url = url + "q=" + city.replace(" ", "+") + "&units=imperial" + "&appid=" + weather_api_key
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        # Append the city information into city_data list
        city_data.append({'City': city.title(),
                        'Country': city_country,
                         'Lat': city_lat,
                         'Lng': city_lng,
                         'Max Temp': city_max_temp,
                         'Humidity': city_humidity,
                         'Cloudiness': city_clouds,
                         'Wind Speed': city_wind,
                         'Current Description': city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete
print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# Beginning data retrieval
# -----------------------------
# Processing Record 1 of Set 1 | malanje
# Processing Record 2 of Set 1 | kavaratti
# Processing Record 3 of Set 1 | bonavista
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | pathein
# Processing Record 7 of Set 1 | nicoya
# Processing Record 8 of Set 1 | ucluelet
# Processing Record 9 of Set 1 | sribne
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | atagay
# Processing Record 12 of Set 1 | shimoda
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | iqaluit
# Processing Record 16 of Set 1 | umm lajj
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | tome-acu
# City not found. Skipping...
# Processing Record 19 of Set 1 | mirnyy
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | nyzhnya duvanka
# Processing Record 22 of Set 1 | cabo san lucas
# Processing Record 23 of Set 1 | uyskoye
# Processing Record 24 of Set 1 | vavoua
# Processing Record 25 of Set 1 | aswan
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | faanui
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | mangrol
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | qui nhon
# Processing Record 37 of Set 1 | nakamura
# Processing Record 38 of Set 1 | sinegorskiy
# Processing Record 39 of Set 1 | prince rupert
# Processing Record 40 of Set 1 | norman wells
# Processing Record 41 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | meghradzor
# Processing Record 47 of Set 1 | vila franca do campo
# Processing Record 48 of Set 1 | codrington
# Processing Record 49 of Set 1 | zuwarah
# Processing Record 50 of Set 1 | kahului
# Processing Record 52 of Set 2 | cape town
# Processing Record 53 of Set 2 | pandan
# Processing Record 54 of Set 2 | bollnas
# Processing Record 55 of Set 2 | cherskiy
# Processing Record 56 of Set 2 | ixtapa
# Processing Record 57 of Set 2 | victoria
# Processing Record 58 of Set 2 | port elizabeth
# Processing Record 59 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 60 of Set 2 | tuktoyaktuk
# Processing Record 61 of Set 2 | tongren
# Processing Record 62 of Set 2 | riberalta
# Processing Record 63 of Set 2 | vestmanna
# Processing Record 64 of Set 2 | castro
# Processing Record 65 of Set 2 | kaitangata
# Processing Record 66 of Set 2 | albany
# Processing Record 67 of Set 2 | barroualie
# City not found. Skipping...
# Processing Record 68 of Set 2 | digras
# Processing Record 69 of Set 2 | puerto escondido
# Processing Record 70 of Set 2 | rawah
# Processing Record 71 of Set 2 | dumas
# Processing Record 72 of Set 2 | georgetown
# Processing Record 73 of Set 2 | mataura
# Processing Record 74 of Set 2 | cayenne
# Processing Record 75 of Set 2 | provideniya
# Processing Record 76 of Set 2 | bosaso
# Processing Record 77 of Set 2 | mecca
# Processing Record 78 of Set 2 | nioki
# Processing Record 79 of Set 2 | narsaq
# Processing Record 80 of Set 2 | tasiilaq
# Processing Record 81 of Set 2 | wattegama
# Processing Record 82 of Set 2 | igboho
# Processing Record 83 of Set 2 | zaqatala
# Processing Record 84 of Set 2 | juneau
# Processing Record 85 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 86 of Set 2 | hermanus
# Processing Record 87 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 88 of Set 2 | montceau-les-mines
# Processing Record 89 of Set 2 | pinega
# Processing Record 90 of Set 2 | santiago
# Processing Record 91 of Set 2 | butaritari
# Processing Record 92 of Set 2 | mar del plata
# Processing Record 93 of Set 2 | nizhniy kuranakh
# Processing Record 94 of Set 2 | lazaro cardenas
# Processing Record 95 of Set 2 | pacific grove
# Processing Record 96 of Set 2 | fortuna
# Processing Record 97 of Set 2 | saint-philippe
# Processing Record 98 of Set 2 | abha
# Processing Record 99 of Set 2 | kuala terengganu
# Processing Record 100 of Set 2 | port alfred
# Processing Record 101 of Set 2 | pevek
# Processing Record 103 of Set 3 | ye
# City not found. Skipping...
# Processing Record 104 of Set 3 | longyearbyen
# Processing Record 105 of Set 3 | buchanan
# Processing Record 106 of Set 3 | pointe michel
# Processing Record 107 of Set 3 | pucallpa
# Processing Record 108 of Set 3 | pychas
# Processing Record 109 of Set 3 | lebu
# Processing Record 110 of Set 3 | nikolskoye
# Processing Record 111 of Set 3 | makeni
# Processing Record 112 of Set 3 | chapais
# Processing Record 113 of Set 3 | dingle
# Processing Record 114 of Set 3 | srednekolymsk
# Processing Record 115 of Set 3 | severo-kurilsk
# Processing Record 116 of Set 3 | jamestown
# Processing Record 117 of Set 3 | mattru
# Processing Record 118 of Set 3 | lithgow
# Processing Record 119 of Set 3 | anadyr
# Processing Record 120 of Set 3 | mali
# Processing Record 121 of Set 3 | chokurdakh
# Processing Record 122 of Set 3 | felidhoo
# City not found. Skipping...
# Processing Record 123 of Set 3 | souillac
# Processing Record 124 of Set 3 | atuona
# Processing Record 125 of Set 3 | broome
# Processing Record 126 of Set 3 | hasaki
# Processing Record 127 of Set 3 | labuhan
# Processing Record 128 of Set 3 | kuvshinovo
# Processing Record 129 of Set 3 | constitucion
# Processing Record 130 of Set 3 | hami
# Processing Record 131 of Set 3 | mezen
# Processing Record 132 of Set 3 | alofi
# Processing Record 133 of Set 3 | ponta do sol
# Processing Record 134 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 135 of Set 3 | pendleton
# Processing Record 136 of Set 3 | aberdeen
# Processing Record 137 of Set 3 | neyshabur
# Processing Record 138 of Set 3 | torres
# Processing Record 139 of Set 3 | ancud
# Processing Record 140 of Set 3 | inhambane
# Processing Record 141 of Set 3 | raleigh
# Processing Record 142 of Set 3 | morondava
# Processing Record 143 of Set 3 | koutiala
# Processing Record 144 of Set 3 | atar
# Processing Record 145 of Set 3 | evensk
# Processing Record 146 of Set 3 | bethel
# Processing Record 147 of Set 3 | priiskovyy
# Processing Record 148 of Set 3 | san patricio
# Processing Record 149 of Set 3 | manono
# Processing Record 150 of Set 3 | livingston
# Processing Record 151 of Set 3 | karasjok
# Processing Record 152 of Set 3 | geraldton
# Processing Record 154 of Set 4 | mandurah
# Processing Record 155 of Set 4 | gizo
# Processing Record 156 of Set 4 | klimovo
# Processing Record 157 of Set 4 | umm kaddadah
# Processing Record 158 of Set 4 | zhanaozen
# Processing Record 159 of Set 4 | monrovia
# Processing Record 160 of Set 4 | miandrivazo
# Processing Record 161 of Set 4 | terrace
# Processing Record 162 of Set 4 | khatanga
# Processing Record 163 of Set 4 | qaqortoq
# Processing Record 164 of Set 4 | chara
# Processing Record 165 of Set 4 | tuatapere
# Processing Record 166 of Set 4 | yaan
# Processing Record 167 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 168 of Set 4 | bambous virieux
# Processing Record 169 of Set 4 | black river
# Processing Record 170 of Set 4 | grand gaube
# Processing Record 171 of Set 4 | byron bay
# Processing Record 172 of Set 4 | viru
# Processing Record 173 of Set 4 | lompoc
# Processing Record 174 of Set 4 | chuy
# Processing Record 175 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 176 of Set 4 | saint george
# Processing Record 177 of Set 4 | hofn
# Processing Record 178 of Set 4 | swan hill
# Processing Record 179 of Set 4 | fairmont
# Processing Record 180 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 181 of Set 4 | zhenhai
# Processing Record 182 of Set 4 | mahenge
# Processing Record 183 of Set 4 | gubkinskiy
# Processing Record 184 of Set 4 | pundaguitan
# Processing Record 185 of Set 4 | menongue
# Processing Record 186 of Set 4 | mizdah
# Processing Record 187 of Set 4 | kokopo
# Processing Record 188 of Set 4 | lorengau
# Processing Record 189 of Set 4 | erzin
# Processing Record 190 of Set 4 | caravelas
# Processing Record 191 of Set 4 | vestmannaeyjar
# Processing Record 192 of Set 4 | orangeburg
# Processing Record 193 of Set 4 | borgo san dalmazzo
# Processing Record 194 of Set 4 | torbay
# Processing Record 195 of Set 4 | nyrob
# Processing Record 196 of Set 4 | tucurui
# Processing Record 197 of Set 4 | sri aman
# Processing Record 198 of Set 4 | hualmay
# Processing Record 199 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 200 of Set 4 | varkaus
# Processing Record 201 of Set 4 | praya
# Processing Record 202 of Set 4 | kodiak
# Processing Record 203 of Set 4 | oranjemund
# Processing Record 205 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 206 of Set 5 | sao filipe
# Processing Record 207 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 208 of Set 5 | lom sak
# Processing Record 209 of Set 5 | saskylakh
# Processing Record 210 of Set 5 | prince george
# Processing Record 211 of Set 5 | santa rosalia
# Processing Record 212 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 213 of Set 5 | usinsk
# Processing Record 214 of Set 5 | charagua
# Processing Record 215 of Set 5 | la ronge
# Processing Record 216 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 217 of Set 5 | saldanha
# Processing Record 218 of Set 5 | manavalakurichi
# Processing Record 219 of Set 5 | nasrullaganj
# City not found. Skipping...
# Processing Record 220 of Set 5 | port moresby
# Processing Record 221 of Set 5 | hithadhoo
# Processing Record 222 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 223 of Set 5 | tucuman
# Processing Record 224 of Set 5 | walvis bay
# Processing Record 225 of Set 5 | vila velha
# Processing Record 226 of Set 5 | chumphon
# Processing Record 227 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 228 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 229 of Set 5 | buala
# Processing Record 230 of Set 5 | sergeyevka
# Processing Record 231 of Set 5 | margate
# Processing Record 232 of Set 5 | awjilah
# Processing Record 233 of Set 5 | kruisfontein
# Processing Record 234 of Set 5 | san cristobal
# Processing Record 235 of Set 5 | portsmouth
# Processing Record 236 of Set 5 | yulara
# Processing Record 237 of Set 5 | krasnoselkup
# Processing Record 238 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 239 of Set 5 | chilca
# Processing Record 240 of Set 5 | sinaloa
# Processing Record 241 of Set 5 | mutis
# Processing Record 242 of Set 5 | maumere
# Processing Record 243 of Set 5 | upernavik
# Processing Record 244 of Set 5 | port macquarie
# Processing Record 245 of Set 5 | zhangjiakou
# Processing Record 246 of Set 5 | namatanai
# Processing Record 247 of Set 5 | dawson creek
# Processing Record 248 of Set 5 | san andres
# Processing Record 249 of Set 5 | mahebourg
# Processing Record 250 of Set 5 | ahipara
# Processing Record 251 of Set 5 | myrtle beach
# Processing Record 252 of Set 5 | port lincoln
# Processing Record 253 of Set 5 | thompson
# Processing Record 254 of Set 5 | nyurba
# Processing Record 256 of Set 6 | dohar
# Processing Record 257 of Set 6 | haines junction
# Processing Record 258 of Set 6 | sorland
# Processing Record 259 of Set 6 | lata
# Processing Record 260 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 261 of Set 6 | borlange
# City not found. Skipping...
# Processing Record 262 of Set 6 | havoysund
# Processing Record 263 of Set 6 | moerai
# Processing Record 264 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 265 of Set 6 | takoradi
# Processing Record 266 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 267 of Set 6 | jand
# Processing Record 268 of Set 6 | puerto ayacucho
# Processing Record 269 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 270 of Set 6 | nishihara
# Processing Record 271 of Set 6 | carnarvon
# Processing Record 272 of Set 6 | koumac
# Processing Record 273 of Set 6 | luderitz
# Processing Record 274 of Set 6 | carutapera
# Processing Record 275 of Set 6 | ferme-neuve
# Processing Record 276 of Set 6 | quatre cocos
# Processing Record 277 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 278 of Set 6 | barcelona
# Processing Record 279 of Set 6 | limbe
# Processing Record 280 of Set 6 | bilma
# Processing Record 281 of Set 6 | burica
# City not found. Skipping...
# Processing Record 282 of Set 6 | porto novo
# Processing Record 283 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 284 of Set 6 | angoche
# Processing Record 285 of Set 6 | sao desiderio
# Processing Record 286 of Set 6 | eyl
# Processing Record 287 of Set 6 | gat
# Processing Record 288 of Set 6 | beringovskiy
# Processing Record 289 of Set 6 | chikoy
# City not found. Skipping...
# Processing Record 290 of Set 6 | airai
# Processing Record 291 of Set 6 | taburao
# City not found. Skipping...
# Processing Record 292 of Set 6 | denpasar
# Processing Record 293 of Set 6 | guerrero negro
# Processing Record 294 of Set 6 | biu
# Processing Record 295 of Set 6 | kinablangan
# Processing Record 296 of Set 6 | teguise
# Processing Record 297 of Set 6 | komsomolskiy
# Processing Record 298 of Set 6 | goderich
# Processing Record 299 of Set 6 | sosnovo-ozerskoye
# Processing Record 300 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 301 of Set 6 | kismayo
# Processing Record 302 of Set 6 | vasilsursk
# Processing Record 303 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 304 of Set 6 | duncan
# Processing Record 305 of Set 6 | rocha
# Processing Record 307 of Set 7 | sangar
# Processing Record 308 of Set 7 | deputatskiy
# Processing Record 309 of Set 7 | bathsheba
# Processing Record 310 of Set 7 | garissa
# Processing Record 311 of Set 7 | hamilton
# Processing Record 312 of Set 7 | lewistown
# Processing Record 313 of Set 7 | port blair
# Processing Record 314 of Set 7 | adrar
# Processing Record 315 of Set 7 | aitape
# Processing Record 316 of Set 7 | plettenberg bay
# Processing Record 317 of Set 7 | zhob
# Processing Record 318 of Set 7 | san quintin
# Processing Record 319 of Set 7 | syamzha
# Processing Record 320 of Set 7 | conselice
# Processing Record 321 of Set 7 | poronaysk
# Processing Record 322 of Set 7 | hobyo
# Processing Record 323 of Set 7 | hoquiam
# Processing Record 324 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 325 of Set 7 | cidreira
# Processing Record 326 of Set 7 | bata
# Processing Record 327 of Set 7 | batagay-alyta
# Processing Record 328 of Set 7 | malartic
# Processing Record 329 of Set 7 | dali
# Processing Record 330 of Set 7 | mandalgovi
# Processing Record 331 of Set 7 | katsuura
# Processing Record 332 of Set 7 | praia da vitoria
# Processing Record 333 of Set 7 | portland
# Processing Record 334 of Set 7 | mahanoro
# Processing Record 335 of Set 7 | kattivakkam
# Processing Record 336 of Set 7 | qujing
# Processing Record 337 of Set 7 | kendari
# Processing Record 338 of Set 7 | maceio
# Processing Record 339 of Set 7 | olafsvik
# Processing Record 340 of Set 7 | nikki
# Processing Record 341 of Set 7 | itoman
# Processing Record 342 of Set 7 | tabukiniberu
# City not found. Skipping...
# Processing Record 343 of Set 7 | dekoa
# City not found. Skipping...
# Processing Record 344 of Set 7 | bubaque
# Processing Record 345 of Set 7 | gomel
# Processing Record 346 of Set 7 | grindavik
# Processing Record 347 of Set 7 | sakakah
# Processing Record 348 of Set 7 | camacha
# Processing Record 349 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 350 of Set 7 | sabzevar
# Processing Record 351 of Set 7 | chabahar
# Processing Record 352 of Set 7 | lensk
# Processing Record 353 of Set 7 | avarua
# Processing Record 354 of Set 7 | atikokan
# Processing Record 355 of Set 7 | udachnyy
# Processing Record 356 of Set 7 | tahoua
# Processing Record 358 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 359 of Set 8 | santa cruz
# Processing Record 360 of Set 8 | banda aceh
# Processing Record 361 of Set 8 | kuchera
# Processing Record 362 of Set 8 | labrea
# Processing Record 363 of Set 8 | ayakudi
# Processing Record 364 of Set 8 | waddan
# Processing Record 365 of Set 8 | zhicheng
# Processing Record 366 of Set 8 | solnechnyy
# Processing Record 367 of Set 8 | olinda
# Processing Record 368 of Set 8 | clearwater
# Processing Record 369 of Set 8 | zlitan
# Processing Record 370 of Set 8 | pravdinsk
# Processing Record 371 of Set 8 | caranavi
# Processing Record 372 of Set 8 | nampula
# Processing Record 373 of Set 8 | gimli
# Processing Record 374 of Set 8 | bonoua
# Processing Record 375 of Set 8 | ottawa
# Processing Record 376 of Set 8 | yatou
# Processing Record 377 of Set 8 | meulaboh
# Processing Record 378 of Set 8 | valparaiso
# Processing Record 379 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 380 of Set 8 | collie
# Processing Record 381 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 382 of Set 8 | pisco
# Processing Record 383 of Set 8 | vardo
# Processing Record 384 of Set 8 | kamaishi
# Processing Record 385 of Set 8 | nanortalik
# Processing Record 386 of Set 8 | shelton
# Processing Record 387 of Set 8 | el viejo
# Processing Record 388 of Set 8 | luwuk
# Processing Record 389 of Set 8 | boca do acre
# Processing Record 390 of Set 8 | palmer
# Processing Record 391 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 392 of Set 8 | wilmington
# Processing Record 393 of Set 8 | husavik
# Processing Record 394 of Set 8 | lianran
# Processing Record 395 of Set 8 | dikson
# Processing Record 396 of Set 8 | guangyuan
# Processing Record 397 of Set 8 | bartica
# Processing Record 398 of Set 8 | san lorenzo
# Processing Record 399 of Set 8 | lakes entrance
# Processing Record 400 of Set 8 | mikkeli
# Processing Record 401 of Set 8 | ulu-telyak
# Processing Record 402 of Set 8 | kisumu
# Processing Record 403 of Set 8 | korla
# Processing Record 404 of Set 8 | skoghall
# Processing Record 405 of Set 8 | bonfim
# Processing Record 406 of Set 8 | floro
# Processing Record 407 of Set 8 | lucea
# Processing Record 409 of Set 9 | tezu
# Processing Record 410 of Set 9 | shihezi
# Processing Record 411 of Set 9 | acarau
# Processing Record 412 of Set 9 | tallahassee
# Processing Record 413 of Set 9 | lima
# Processing Record 414 of Set 9 | saint-augustin
# Processing Record 415 of Set 9 | richards bay
# Processing Record 416 of Set 9 | kloulklubed
# Processing Record 417 of Set 9 | republic
# Processing Record 418 of Set 9 | tocopilla
# Processing Record 419 of Set 9 | enderby
# Processing Record 420 of Set 9 | namibe
# Processing Record 421 of Set 9 | omboue
# Processing Record 422 of Set 9 | puerto baquerizo moreno
# Processing Record 423 of Set 9 | kutum
# Processing Record 424 of Set 9 | gamba
# Processing Record 425 of Set 9 | nacunday
# City not found. Skipping...
# Processing Record 426 of Set 9 | tual
# Processing Record 427 of Set 9 | maldonado
# Processing Record 428 of Set 9 | mopti
# Processing Record 429 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 430 of Set 9 | borzya
# Processing Record 431 of Set 9 | alta
# Processing Record 432 of Set 9 | rocky mount
# Processing Record 433 of Set 9 | naze
# Processing Record 434 of Set 9 | cockburn town
# Processing Record 435 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 436 of Set 9 | ambilobe
# Processing Record 437 of Set 9 | itacare
# Processing Record 438 of Set 9 | tateyama
# Processing Record 439 of Set 9 | carmen
# Processing Record 440 of Set 9 | antofagasta
# Processing Record 441 of Set 9 | manado
# Processing Record 442 of Set 9 | kieta
# Processing Record 443 of Set 9 | vung tau
# Processing Record 444 of Set 9 | karratha
# Processing Record 445 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 446 of Set 9 | cabedelo
# Processing Record 447 of Set 9 | albertville
# Processing Record 448 of Set 9 | knysna
# Processing Record 449 of Set 9 | kytlym
# City not found. Skipping...
# Processing Record 450 of Set 9 | santa isabel do rio negro
# Processing Record 451 of Set 9 | shingu
# Processing Record 452 of Set 9 | monte patria
# Processing Record 453 of Set 9 | yarim
# Processing Record 454 of Set 9 | noumea
# Processing Record 455 of Set 9 | alberton
# Processing Record 456 of Set 9 | nagato
# Processing Record 457 of Set 9 | ostrovnoy
# Processing Record 458 of Set 9 | aztec
# Processing Record 460 of Set 10 | nizwa
# Processing Record 461 of Set 10 | belaya gora
# Processing Record 462 of Set 10 | ust-maya
# Processing Record 463 of Set 10 | vao
# Processing Record 464 of Set 10 | potgietersrus
# City not found. Skipping...
# Processing Record 465 of Set 10 | maua
# Processing Record 466 of Set 10 | englewood
# Processing Record 467 of Set 10 | mocuba
# Processing Record 468 of Set 10 | berlevag
# Processing Record 469 of Set 10 | villa bruzual
# Processing Record 470 of Set 10 | ilulissat
# Processing Record 471 of Set 10 | wenzhou
# Processing Record 472 of Set 10 | tamworth
# Processing Record 473 of Set 10 | smithers
# Processing Record 474 of Set 10 | jibuti
# Processing Record 475 of Set 10 | lipin bor
# Processing Record 476 of Set 10 | dovolnoye
# Processing Record 477 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 478 of Set 10 | weatherford
# Processing Record 479 of Set 10 | seoul
# Processing Record 480 of Set 10 | moffat
# Processing Record 481 of Set 10 | tavda
# Processing Record 482 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 483 of Set 10 | hervey bay
# Processing Record 484 of Set 10 | lewisporte
# Processing Record 485 of Set 10 | kautokeino
# Processing Record 486 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 487 of Set 10 | comodoro rivadavia
# Processing Record 488 of Set 10 | peterhead
# Processing Record 489 of Set 10 | alihe
# Processing Record 490 of Set 10 | ebano
# City not found. Skipping...
# Processing Record 491 of Set 10 | east london
# Processing Record 492 of Set 10 | christchurch
# Processing Record 493 of Set 10 | kurilsk
# Processing Record 494 of Set 10 | leshukonskoye
# Processing Record 495 of Set 10 | hambantota
# Processing Record 496 of Set 10 | maragogi
# Processing Record 497 of Set 10 | nouadhibou
# Processing Record 498 of Set 10 | grimari
# City not found. Skipping...
# Processing Record 499 of Set 10 | sao jose da coroa grande
# Processing Record 500 of Set 10 | milkovo
# Processing Record 501 of Set 10 | san policarpo
# Processing Record 502 of Set 10 | nuevitas
# Processing Record 503 of Set 10 | nuristan
# Processing Record 504 of Set 10 | leningradskiy
# Processing Record 505 of Set 10 | khasan
# Processing Record 506 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 507 of Set 10 | kitimat
# Processing Record 508 of Set 10 | aklavik
# Processing Record 509 of Set 10 | aksay
# Processing Record 511 of Set 11 | point pedro
# Processing Record 512 of Set 11 | kununurra
# Processing Record 513 of Set 11 | bonthe
# Processing Record 514 of Set 11 | esperance
# Processing Record 515 of Set 11 | kalmunai
# Processing Record 516 of Set 11 | dunedin
# Processing Record 517 of Set 11 | jaciara
# Processing Record 518 of Set 11 | zhigansk
# Processing Record 519 of Set 11 | lukulu
# Processing Record 520 of Set 11 | watertown
# Processing Record 521 of Set 11 | pocosol
# Processing Record 522 of Set 11 | dorfen
# Processing Record 523 of Set 11 | ugoofaaru
# Processing Record 524 of Set 11 | westerland
# Processing Record 525 of Set 11 | banepa
# Processing Record 526 of Set 11 | clyde river
# Processing Record 527 of Set 11 | luena
# Processing Record 528 of Set 11 | zambezi
# Processing Record 529 of Set 11 | duz
# City not found. Skipping...
# Processing Record 530 of Set 11 | billings
# Processing Record 531 of Set 11 | rio gallegos
# Processing Record 532 of Set 11 | salalah
# Processing Record 533 of Set 11 | shenjiamen
# Processing Record 534 of Set 11 | touros
# Processing Record 535 of Set 11 | viedma
# Processing Record 536 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 537 of Set 11 | hongjiang
# Processing Record 538 of Set 11 | tautira
# Processing Record 539 of Set 11 | benicarlo
# Processing Record 540 of Set 11 | tessalit
# Processing Record 541 of Set 11 | grootfontein
# Processing Record 542 of Set 11 | te anau
# Processing Record 543 of Set 11 | cosala
# Processing Record 544 of Set 11 | ornskoldsvik
# Processing Record 545 of Set 11 | tarakan
# Processing Record 546 of Set 11 | agadez
# Processing Record 547 of Set 11 | bone
# Processing Record 548 of Set 11 | oksfjord
# Processing Record 549 of Set 11 | peque
# Processing Record 550 of Set 11 | la palma
# Processing Record 551 of Set 11 | dulce nombre de culmi
# Processing Record 552 of Set 11 | mumford
# Processing Record 553 of Set 11 | whitecourt
# Processing Record 554 of Set 11 | khorixas
# Processing Record 555 of Set 11 | mariinsk
# Processing Record 556 of Set 11 | eenhana
# Processing Record 557 of Set 11 | harper
# Processing Record 558 of Set 11 | sidi ali
# Processing Record 559 of Set 11 | wamba
# Processing Record 560 of Set 11 | sao joao da barra
# Processing Record 562 of Set 12 | zverinogolovskoye
# Processing Record 563 of Set 12 | talnakh
# Processing Record 564 of Set 12 | simpang
# Processing Record 565 of Set 12 | high level
# Processing Record 566 of Set 12 | horsham
# Processing Record 567 of Set 12 | mangit
# Processing Record 568 of Set 12 | ulladulla
# Processing Record 569 of Set 12 | san jeronimo
# Processing Record 570 of Set 12 | hachinohe
# Processing Record 571 of Set 12 | hefei
# Processing Record 572 of Set 12 | estacion coahuila
# Processing Record 573 of Set 12 | todos santos
# Processing Record 574 of Set 12 | velyka bahachka
# Processing Record 575 of Set 12 | espinosa
# Processing Record 576 of Set 12 | bay-khaak
# Processing Record 577 of Set 12 | choma
# Processing Record 578 of Set 12 | vaitape
# Processing Record 579 of Set 12 | terra santa
# Processing Record 580 of Set 12 | zandvoort
# Processing Record 581 of Set 12 | faya
# Processing Record 582 of Set 12 | tevaitoa
# Processing Record 583 of Set 12 | rimouski
# Processing Record 584 of Set 12 | zaplavnoye
# Processing Record 585 of Set 12 | fort nelson
# Processing Record 586 of Set 12 | camocim
# Processing Record 587 of Set 12 | otradnoye
# Processing Record 588 of Set 12 | canoa
# Processing Record 589 of Set 12 | eureka
# Processing Record 590 of Set 12 | nuuk
# Processing Record 591 of Set 12 | dunkwa
# Processing Record 592 of Set 12 | bontang
# Processing Record 593 of Set 12 | flin flon
# Processing Record 594 of Set 12 | merauke
# Processing Record 595 of Set 12 | lidkoping
# Processing Record 596 of Set 12 | poum
# Processing Record 597 of Set 12 | kuito
# Processing Record 598 of Set 12 | kenai
# Processing Record 599 of Set 12 | cururupu
# Processing Record 600 of Set 12 | lavrentiya
# Processing Record 601 of Set 12 | half moon bay
# Processing Record 602 of Set 12 | veraval
# Processing Record 603 of Set 12 | chimore
# Processing Record 604 of Set 12 | najran
# Processing Record 605 of Set 12 | kavieng
# Processing Record 606 of Set 12 | santiago del estero
# Processing Record 607 of Set 12 | thinadhoo
# Processing Record 608 of Set 12 | arkhangelskaya
# Processing Record 609 of Set 12 | papayal
# Processing Record 610 of Set 12 | los llanos de aridane
# Processing Record 611 of Set 12 | brae
# Processing Record 613 of Set 13 | chitipa
# Processing Record 614 of Set 13 | bokoro
# Processing Record 615 of Set 13 | erdaojiang
# Processing Record 616 of Set 13 | tornyospalca
# Processing Record 617 of Set 13 | lagoa
# Processing Record 618 of Set 13 | calvia
# Processing Record 619 of Set 13 | sioux lookout
# Processing Record 620 of Set 13 | oriximina
# Processing Record 621 of Set 13 | lasa
# Processing Record 622 of Set 13 | okhotsk
# Processing Record 623 of Set 13 | lososina
# Processing Record 624 of Set 13 | broken hill
# Processing Record 625 of Set 13 | abu samrah
# Processing Record 626 of Set 13 | luyang
# Processing Record 627 of Set 13 | hokitika
# Processing Record 628 of Set 13 | bantogon
# Processing Record 629 of Set 13 | krasnodon
# Processing Record 630 of Set 13 | totma
# Processing Record 631 of Set 13 | aksarka
# Processing Record 632 of Set 13 | redding
# Processing Record 633 of Set 13 | bengkulu
# Processing Record 634 of Set 13 | kargil
# Processing Record 635 of Set 13 | luba
# Processing Record 636 of Set 13 | sarkand
# Processing Record 637 of Set 13 | coihaique
# Processing Record 638 of Set 13 | wasilla
# Processing Record 639 of Set 13 | dawei
# Processing Record 640 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 641 of Set 13 | yeppoon
# Processing Record 642 of Set 13 | kirakira
# Processing Record 643 of Set 13 | tabat
# Processing Record 644 of Set 13 | vilhena
# Processing Record 645 of Set 13 | nhulunbuy
# Processing Record 646 of Set 13 | zinder
# Processing Record 647 of Set 13 | mbuguni
# Processing Record 648 of Set 13 | shubarkuduk
# Processing Record 649 of Set 13 | behshahr
# Processing Record 650 of Set 13 | padang
# Processing Record 651 of Set 13 | naples
# Processing Record 652 of Set 13 | tomino
# Processing Record 653 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 654 of Set 13 | saint-joseph
# Processing Record 655 of Set 13 | missoula
# Processing Record 656 of Set 13 | voyvozh
# Processing Record 657 of Set 13 | yefira
# City not found. Skipping...
# Processing Record 658 of Set 13 | swan river
# Processing Record 659 of Set 13 | maniitsoq
# Processing Record 660 of Set 13 | yenagoa
# Processing Record 661 of Set 13 | kuznechnoye
# Processing Record 662 of Set 13 | port augusta
# Processing Record 664 of Set 14 | wadena
# -------------------------
# Data Retrieval Complete
# -------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Malanje      AO  -9.5402   16.3410     87.71        12           0
# 1    Kavaratti      IN  10.5669   72.6420     82.62        82         100
# 2    Bonavista      CA  48.6499  -53.1147     64.18        61          43
# 3        Tiksi      RU  71.6872  128.8694     39.96        91          53
# 4  New Norfolk      AU -42.7826  147.0587     53.10        65         100
# 5      Pathein      MM  16.7833   94.7333     79.03        90         100
# 6       Nicoya      CR  10.1483  -85.4520     87.35        71          47
# 7     Ucluelet      CA  48.9329 -125.5528     71.04        93         100
# 8       Sribne      UA  50.6638   32.9187     68.79        81          98
# 9  Yellowknife      CA  62.4560 -114.3525     58.32        76          96
#
#    Wind Speed Current Description
# 0        2.75           clear sky
# 1       16.75     overcast clouds
# 2        3.13    scattered clouds
# 3        8.68       broken clouds
# 4        5.01     overcast clouds
# 5       10.29     overcast clouds
# 6        3.20    scattered clouds
# 7        3.44     overcast clouds
# 8        3.51     overcast clouds
# 9        2.33     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
